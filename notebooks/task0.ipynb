# %% [markdown]
# # Part I: Data Collection

# %% [markdown]
# In this section, we will collect the data that we will work on in the following sections. For this project, we will be working with stock data from Bourse de Casablanca

# %% [markdown]
# - Head over here and select a sector with at least 5 instruments. (ie Assurances, Banques, Bâtiments et matériaux deconstruction...).

# %% [markdown]
# - From this sector, select 5 instruments that you will work on.

# %% [markdown]
# - For each instrument, head over to its data page by clicking on it. For example, this is the page for Aluminium du Maroc. Choose the historique tab, and toggle the selection to Par période, then, choose 01/01/2020 for Date de début and01/12/2022 for Date de fin.

# %% [markdown]
# For this part We choose the "Sociétés de financement et d'autre activités financieres " section which contains exactly 5 instruments as shown in the picture below

# %% [markdown]
# ![Picture title](img/image-20230102-173407.png)

# %% [markdown]
# for each instrument we downloaded the data from01/01/2020 to 01/12/2022 in a .aspx format using the following links:

# %% [markdown]
# undefined. https://www.casablanca-bourse.com/bourseweb/Societe-Cote.aspx?codeValeur=4200&cat=7

# %% [markdown]
# undefined. https://www.casablanca-bourse.com/bourseweb/Societe-Cote.aspx?codeValeur=2300&cat=7

# %% [markdown]
# undefined. https://www.casablanca-bourse.com/bourseweb/Societe-Cote.aspx?codeValeur=1600&cat=7

# %% [markdown]
# undefined. https://www.casablanca-bourse.com/bourseweb/Societe-Cote.aspx?codeValeur=2500&cat=7

# %% [markdown]
# undefined. https://www.casablanca-bourse.com/bourseweb/Societe-Cote.aspx?codeValeur=10700&cat=7

# %% [markdown]
# So The output files  for this part are in the folder " Dataset" in the FILES section

# %% [markdown]
# DIAC_SALAF

# %% [markdown]
# EQDOM

# %% [markdown]
# MAGHREBAIL

# %% [markdown]
# MAROC LEASING

# %% [markdown]
# SLAFIN

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8eeb6fb9-2d6b-464e-b219-535fd1ffa708' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
