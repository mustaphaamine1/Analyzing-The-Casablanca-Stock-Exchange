# %% [markdown]
# # Task4 : Methods for the stock class

# %% [markdown]
# Inside Stock, create the following instance methods:

# %% [markdown]
# - a method that returns the maximum value in the Dataframe.

# %% [markdown]
# - a method that returns the minimum value in the Dataframe.

# %% [markdown]
# - a method that returns the maximum volume in the Dataframe.

# %% [markdown]
# - a method that returns the maximum quantity in the Dataframe.

# %% [markdown]
# Let's start by creating the methods:

# %% [markdown]
# ### Step1 : Creating the functions

# %%
#importing the functions file
import sys  
sys.path.insert(0, '/root/work/functions.py')
from functions import *

# %%
class Stock:

    def __init__(self, name):
        self.name = name
        self.data = create_dataframe(name+'.aspx')
        
s3 = Stock('MAGHREBAIL')

# %%
s3.data
# Out:
#           date  closing  adjusted  evolution  quantity  volume
# 0   2020-01-04    962.0     962.0        0.0       0.0     0.0
# 1   2020-01-06    962.0     962.0        0.0       0.0     0.0
# 2   2020-01-07    962.0     962.0        0.0       0.0     0.0
# 3   2020-01-09    876.0     876.0        0.0       0.0     0.0
# 4   2020-01-10    889.0     889.0        0.0       0.0     0.0
# ..         ...      ...       ...        ...       ...     ...
# 727 2022-12-05    883.0     883.0        0.0       0.0     0.0
# 728 2022-12-07    821.0     821.0        0.0       0.0     0.0
# 729 2022-12-08    830.0     830.0        0.0       0.0     0.0
# 730 2022-12-09    883.0     883.0        0.0       0.0     0.0
# 731 2022-12-10    860.1     860.1        0.0       0.0     0.0
#
# [732 rows x 6 columns]

# %%
def return_max(data):
    return max(data['closing'])
def return_min(data):
    return min(data['closing'])
def volume_max(data):
    return max(data['volume'])
def quantity_max(data):
    return max(data['quantity'])

# %%
print(return_max(s3.data))
print(return_min(s3.data))
print(volume_max(s3.data))
print(quantity_max(s3.data))
# Out:
# 962.0
# 755.0
# 30743280.0
# 35748.0

# %% [markdown]
# ### Step2: Adding the functions as methods for the class stock

# %%
class Stock:

    def __init__(self, name):
        self.name = name
        self.data = create_dataframe(name+'.aspx')
        
    #methods to get the max and min of different columns
    def return_max(self):
        return max(self.data['closing'])
    def return_min(self):
        return min(self.data['closing'])
    def volume_max(self):
        return max(self.data['volume'])
    def quantity_max(self):
        return max(self.data['quantity'])

# %%
s3 = Stock('MAGHREBAIL')
s3.volume_max()
# Out:
# 30743280.0

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8eeb6fb9-2d6b-464e-b219-535fd1ffa708' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
