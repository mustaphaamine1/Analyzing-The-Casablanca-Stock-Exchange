# %% [markdown]
# # Analyzing The Casablanca Stock Exchange

# %% [markdown]
# This is a project done by me Mustapha AMINE and  Ilham LAGHRISSI for the course Advanced Python Programming

# %% [markdown]
# Supervisor:       Pr. A.Ratnani

# %% [markdown]
# Co-Supervisors:        J,Maaouni    &   N.Ouhaddou

# %% [markdown]
# # Objectives of the Project  :

# %% [markdown]
# In this guided project we gain first-hand experience with a real problem, apply the skills that you learned before, and be proficient in:

# %% [markdown]
# - Data collection and cleaning.

# %% [markdown]
# - Data Analysis and visualization with Pandas and Matplotlib.

# %% [markdown]
# - Python object-oriented programming.

# %% [markdown]
# - Problem-Solving and learning new algorithms used in Finance

# %% [markdown]
# - Code optimization and acceleration

# %% [markdown]
# The project is guided and split into several tasks to be easy to tackle and each task is done in a seperate notebook :

# %% [markdown]
# - Task 0

# %% [markdown]
# - Task 1

# %% [markdown]
# - Task 2

# %% [markdown]
# - Task 3

# %% [markdown]
# - Task 4

# %% [markdown]
# - Task 5

# %% [markdown]
# - Task 6

# %% [markdown]
# - Task 7

# %% [markdown]
# - Task8

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8eeb6fb9-2d6b-464e-b219-535fd1ffa708' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
